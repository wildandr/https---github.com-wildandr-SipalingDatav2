# %%
# !pip3 install pandas-profiling --upgrade

# %%
# pip install shapely==2.0.1 numpy==1.22.1 scipy==1.8.0

# %%
# pip cache purge

# %%
# !pip3 install pyforest

# %%
train = pd.read_csv("/Users/owwl/Downloads/train.csv")
test = pd.read_csv("/Users/owwl/Downloads/test.csv")

# %%
train
# Out:
#           datetime               datetime_iso  time-zone           temp  \
# 0        283996800  1979-01-01 00:00:00+00:00      28800  24.75 Celcius
# 1        284000400  1979-01-01 01:00:00+00:00      28800        24.58 C
# 2        284004000  1979-01-01 02:00:00+00:00      28800   26.6 Celcius
# 3        284007600  1979-01-01 03:00:00+00:00      28800  27.31 Celcius
# 4        284011200  1979-01-01 04:00:00+00:00      28800          27.41
# ...            ...                        ...        ...            ...
# 341875  1514746800  2017-12-31 19:00:00+00:00      28800  25.06 Celcius
# 341876  1514750400  2017-12-31 20:00:00+00:00      28800        24.51°C
# 341877  1514754000  2017-12-31 21:00:00+00:00      28800        24.63 C
# 341878  1514757600  2017-12-31 22:00:00+00:00      28800          26.68
# 341879  1514761200  2017-12-31 23:00:00+00:00      28800        26.49 C
#
#           visibility   d_point     feels min_temp   max_temp       prssr  \
# ...

# %%
train.describe()
# Out:
#            datetime  time-zone
# count  3.418800e+05   341880.0
# mean   8.993790e+08    28800.0
# std    3.552926e+08        0.0
# min    2.839968e+08    28800.0
# 25%    5.916879e+08    28800.0
# 50%    8.993790e+08    28800.0
# 75%    1.207070e+09    28800.0
# max    1.514761e+09    28800.0

# %%
# !pip3 install autoviz

# %%
from autoviz import AutoViz_Class
AV = AutoViz_Class()
dft = AV.AutoViz("/Users/owwl/Downloads/train.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from autoviz import AutoViz_Class
#       2 AV = AutoViz_Class()
#       3 dft = AV.AutoViz("/Users/owwl/Downloads/train.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/autoviz/__init__.py:3
#       1 name = "autoviz"
#       2 from .__version__ import __version__, __holo_version__
# ----> 3 from .AutoViz_Class import AutoViz_Class
#       4 from .AutoViz_Class import data_cleaning_suggestions
#       5 from .AutoViz_Class import FixDQ
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/autoviz/AutoViz_Class.py:61
#      59 from sklearn.model_selection import train_test_split
#      60 ##########################################################################################
# ...

# %%
from holoviews.plotting.bokeh import hex_binning

aggregator = (np.size, np.mean)

hex_binning(aggregator=aggregator)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from holoviews.plotting.bokeh import hex_binning
#       3 aggregator = (np.size, np.mean)
#       5 hex_binning(aggregator=aggregator)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/plotting/bokeh/__init__.py:40
#      38 from .graphs import GraphPlot, NodePlot, TriMeshPlot, ChordPlot
#      39 from .heatmap import HeatMapPlot, RadialHeatMapPlot
# ---> 40 from .hex_tiles import HexTilesPlot
#      41 from .path import PathPlot, PolygonPlot, ContourPlot
#      42 from .plot import GridPlot, LayoutPlot, AdjointLayoutPlot
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/holoviews/plotting/bokeh/hex_tiles.py:22
#      18 from .selection import BokehOverlaySelectionDisplay
# ...
